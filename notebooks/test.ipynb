# %%
# %pip install --upgrade gtfs-realtime-bindings
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gtfs-realtime-bindings
#   Downloading gtfs-realtime-bindings-1.0.0.tar.gz (6.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting protobuf
#   Downloading protobuf-4.25.1-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 KB 3.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from gtfs-realtime-bindings) (59.6.0)
# Building wheels for collected packages: gtfs-realtime-bindings
#   Building wheel for gtfs-realtime-bindings (setup.py) ... done
#   Created wheel for gtfs-realtime-bindings: filename=gtfs_realtime_bindings-1.0.0-py3-none-any.whl size=6015 sha256=413fdfd10d7cd46761a427c0a914beb7c4692357f524985889a25b15d9334b14
#   Stored in directory: /home/daven/.cache/pip/wheels/43/98/27/68e4d1de8bb9d8505cfe412bf9af51e66f3e3bd2c98c849c3f
# Successfully built gtfs-realtime-bindings
# Installing collected packages: protobuf, gtfs-realtime-bindings
# Successfully installed gtfs-realtime-bindings-1.0.0 protobuf-4.25.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.transit import gtfs_realtime_pb2
import urllib

feed = gtfs_realtime_pb2.FeedMessage()
response = urllib.request.urlopen('http://api.tfwm.org.uk/gtfs/trip_updates?app_id=a71e73aa&app_key=cafab30dce91fa4d85747891f8ce9980')
feed.ParseFromString(response.read())
for entity in feed.entity:
  if entity.HasField('trip_update'):
    print(entity)
    break
# Out:
# id: "0"
# trip_update {
#   trip {
#     trip_id: "VJ00194f1d74ccf481acf2347cd84c36de8a30e768"
#     route_id: "11"
#     start_time: "09:50:00"
#     start_date: "20231119"
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 0
#     stop_id: "43000827301"
#     departure {
#       delay: 0
#       time: 1700387400
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 1
#     stop_id: "43000827401"
#     arrival {
#       delay: -2
#       time: 1700387453
#     }
#     departure {
#       delay: -2
#       time: 1700387453
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 2
#     stop_id: "43000827501"
#     arrival {
#       delay: -15
#       time: 1700387519
#     }
#     departure {
#       delay: -15
#       time: 1700387519
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 3
#     stop_id: "43000827601"
#     arrival {
#       delay: -20
#       time: 1700387561
#     }
#     departure {
#       delay: -20
#       time: 1700387561
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 4
#     stop_id: "43000827701"
#     arrival {
#       delay: -18
#       time: 1700387603
#     }
#     departure {
#       delay: -18
#       time: 1700387603
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 5
#     stop_id: "43000851001"
#     arrival {
#       delay: 3
#       time: 1700387645
#     }
#     departure {
#       delay: 3
#       time: 1700387645
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 6
#     stop_id: "43000827802"
#     arrival {
#       delay: -1
#       time: 1700387674
#     }
#     departure {
#       delay: -1
#       time: 1700387674
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 7
#     stop_id: "43000826601"
#     arrival {
#       delay: -13
#       time: 1700387717
#     }
#     departure {
#       delay: -13
#       time: 1700387717
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 8
#     stop_id: "43000826501"
#     arrival {
#       delay: -21
#       time: 1700387777
#     }
#     departure {
#       delay: -21
#       time: 1700387777
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 9
#     stop_id: "43000826902"
#     arrival {
#       delay: -33
#       time: 1700387837
#     }
#     departure {
#       delay: -33
#       time: 1700387837
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 10
#     stop_id: "43000826301"
#     arrival {
#       delay: -48
#       time: 1700387879
#     }
#     departure {
#       delay: -48
#       time: 1700387879
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 11
#     stop_id: "43000826201"
#     arrival {
#       delay: -56
#       time: 1700387899
#     }
#     departure {
#       delay: -56
#       time: 1700387899
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 12
#     stop_id: "43000826102"
#     arrival {
#       delay: -74
#       time: 1700387959
#     }
#     departure {
#       delay: -74
#       time: 1700387959
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 13
#     stop_id: "43000822506"
#     arrival {
#       delay: -52
#       time: 1700388128
#     }
#     departure {
#       delay: 0
#       time: 1700388420
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 14
#     stop_id: "43008291002"
#     arrival {
#       delay: 103
#       time: 1700388594
#     }
#     departure {
#       delay: 103
#       time: 1700388594
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 15
#     stop_id: "43000829101"
#     arrival {
#       delay: 101
#       time: 1700388617
#     }
#     departure {
#       delay: 101
#       time: 1700388617
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 16
#     stop_id: "43000829201"
#     arrival {
#       delay: 95
#       time: 1700388658
#     }
#     departure {
#       delay: 95
#       time: 1700388658
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 17
#     stop_id: "43008290503"
#     arrival {
#       delay: 88
#       time: 1700388698
#     }
#     departure {
#       delay: 88
#       time: 1700388698
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 18
#     stop_id: "43000829401"
#     arrival {
#       delay: 85
#       time: 1700388734
#     }
#     departure {
#       delay: 85
#       time: 1700388734
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 19
#     stop_id: "43000829502"
#     arrival {
#       delay: 92
#       time: 1700388762
#     }
#     departure {
#       delay: 92
#       time: 1700388762
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 20
#     stop_id: "43000829601"
#     arrival {
#       delay: 95
#       time: 1700388796
#     }
#     departure {
#       delay: 95
#       time: 1700388796
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 21
#     stop_id: "43000832102"
#     arrival {
#       delay: 106
#       time: 1700388835
#     }
#     departure {
#       delay: 106
#       time: 1700388835
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 22
#     stop_id: "43000832802"
#     arrival {
#       delay: 99
#       time: 1700388864
#     }
#     departure {
#       delay: 99
#       time: 1700388864
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 23
#     stop_id: "43000832201"
#     arrival {
#       delay: 90
#       time: 1700388899
#     }
#     departure {
#       delay: 90
#       time: 1700388899
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 24
#     stop_id: "43000832301"
#     arrival {
#       delay: 85
#       time: 1700388925
#     }
#     departure {
#       delay: 85
#       time: 1700388925
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 25
#     stop_id: "43000832401"
#     arrival {
#       delay: 83
#       time: 1700388968
#     }
#     departure {
#       delay: 83
#       time: 1700388968
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 26
#     stop_id: "43000832501"
#     arrival {
#       delay: 75
#       time: 1700389020
#     }
#     departure {
#       delay: 75
#       time: 1700389020
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 27
#     stop_id: "43000832601"
#     arrival {
#       delay: 64
#       time: 1700389058
#     }
#     departure {
#       delay: 64
#       time: 1700389058
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 28
#     stop_id: "43000832701"
#     arrival {
#       delay: 58
#       time: 1700389080
#     }
#     departure {
#       delay: 58
#       time: 1700389080
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 29
#     stop_id: "43000835702"
#     arrival {
#       delay: 54
#       time: 1700389120
#     }
#     departure {
#       delay: 54
#       time: 1700389120
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 30
#     stop_id: "43000835601"
#     arrival {
#       delay: 60
#       time: 1700389158
#     }
#     departure {
#       delay: 60
#       time: 1700389158
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 31
#     stop_id: "43000835001"
#     arrival {
#       delay: 72
#       time: 1700389212
#     }
#     departure {
#       delay: 72
#       time: 1700389212
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 32
#     stop_id: "43000835806"
#     arrival {
#       delay: 86
#       time: 1700389286
#     }
#     departure {
#       delay: 0
#       time: 1700389500
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 33
#     stop_id: "43000836002"
#     arrival {
#       delay: -6
#       time: 1700389585
#     }
#     departure {
#       delay: -6
#       time: 1700389585
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 34
#     stop_id: "43008300701"
#     arrival {
#       delay: -39
#       time: 1700389654
#     }
#     departure {
#       delay: -39
#       time: 1700389654
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 35
#     stop_id: "43000836702"
#     arrival {
#       delay: -68
#       time: 1700389780
#     }
#     departure {
#       delay: -68
#       time: 1700389780
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 36
#     stop_id: "43000839802"
#     arrival {
#       delay: -116
#       time: 1700389916
#     }
#     departure {
#       delay: -116
#       time: 1700389916
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 37
#     stop_id: "43000839302"
#     arrival {
#       delay: -107
#       time: 1700389951
#     }
#     departure {
#       delay: -107
#       time: 1700389951
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 38
#     stop_id: "43000839402"
#     arrival {
#       delay: -131
#       time: 1700389998
#     }
#     departure {
#       delay: -131
#       time: 1700389998
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 39
#     stop_id: "43000870302"
#     arrival {
#       delay: -153
#       time: 1700390107
#     }
#     departure {
#       delay: -153
#       time: 1700390107
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 40
#     stop_id: "43008718002"
#     arrival {
#       delay: -197
#       time: 1700390175
#     }
#     departure {
#       delay: -197
#       time: 1700390175
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 41
#     stop_id: "43000875101"
#     arrival {
#       delay: -221
#       time: 1700390263
#     }
#     departure {
#       delay: -221
#       time: 1700390263
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 42
#     stop_id: "43000875317"
#     arrival {
#       delay: -143
#       time: 1700390497
#     }
#     departure {
#       delay: 0
#       time: 1700390760
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 43
#     stop_id: "43000874601"
#     arrival {
#       delay: 73
#       time: 1700390871
#     }
#     departure {
#       delay: 73
#       time: 1700390871
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 44
#     stop_id: "43000874501"
#     arrival {
#       delay: 72
#       time: 1700390903
#     }
#     departure {
#       delay: 72
#       time: 1700390903
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 45
#     stop_id: "43000874103"
#     arrival {
#       delay: 64
#       time: 1700390960
#     }
#     departure {
#       delay: 64
#       time: 1700390960
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 46
#     stop_id: "43000869302"
#     arrival {
#       delay: 38
#       time: 1700391013
#     }
#     departure {
#       delay: 38
#       time: 1700391013
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 47
#     stop_id: "43000869201"
#     arrival {
#       delay: 24
#       time: 1700391065
#     }
#     departure {
#       delay: 24
#       time: 1700391065
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 48
#     stop_id: "43000869101"
#     arrival {
#       delay: 16
#       time: 1700391099
#     }
#     departure {
#       delay: 16
#       time: 1700391099
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 49
#     stop_id: "43000868603"
#     arrival {
#       delay: 9
#       time: 1700391162
#     }
#     departure {
#       delay: 9
#       time: 1700391162
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 50
#     stop_id: "43000868403"
#     arrival {
#       delay: 11
#       time: 1700391208
#     }
#     departure {
#       delay: 11
#       time: 1700391208
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 51
#     stop_id: "43000868202"
#     arrival {
#       delay: -8
#       time: 1700391279
#     }
#     departure {
#       delay: -8
#       time: 1700391279
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 52
#     stop_id: "43000865401"
#     arrival {
#       delay: -3
#       time: 1700391417
#     }
#     departure {
#       delay: 0
#       time: 1700391420
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 53
#     stop_id: "43000865302"
#     arrival {
#       delay: 20
#       time: 1700391492
#     }
#     departure {
#       delay: 20
#       time: 1700391492
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 54
#     stop_id: "43007750102"
#     arrival {
#       delay: 15
#       time: 1700391540
#     }
#     departure {
#       delay: 15
#       time: 1700391540
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 55
#     stop_id: "43000728602"
#     arrival {
#       delay: -6
#       time: 1700391588
#     }
#     departure {
#       delay: -6
#       time: 1700391588
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 56
#     stop_id: "43007751503"
#     arrival {
#       delay: -23
#       time: 1700391647
#     }
#     departure {
#       delay: -23
#       time: 1700391647
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 57
#     stop_id: "43000726501"
#     arrival {
#       delay: -23
#       time: 1700391722
#     }
#     departure {
#       delay: -23
#       time: 1700391722
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 58
#     stop_id: "43000726301"
#     arrival {
#       delay: -18
#       time: 1700391775
#     }
#     departure {
#       delay: -18
#       time: 1700391775
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 59
#     stop_id: "43000726202"
#     arrival {
#       delay: -25
#       time: 1700391799
#     }
#     departure {
#       delay: -25
#       time: 1700391799
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 60
#     stop_id: "43000726101"
#     arrival {
#       delay: -34
#       time: 1700391830
#     }
#     departure {
#       delay: -34
#       time: 1700391830
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 61
#     stop_id: "43000725401"
#     arrival {
#       delay: -38
#       time: 1700391875
#     }
#     departure {
#       delay: -38
#       time: 1700391875
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 62
#     stop_id: "43007300104"
#     arrival {
#       delay: -44
#       time: 1700391916
#     }
#     departure {
#       delay: 0
#       time: 1700391960
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 63
#     stop_id: "43000725102"
#     arrival {
#       delay: 30
#       time: 1700392050
#     }
#     departure {
#       delay: 30
#       time: 1700392050
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 64
#     stop_id: "43000724401"
#     arrival {
#       delay: 1
#       time: 1700392141
#     }
#     departure {
#       delay: 1
#       time: 1700392141
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 65
#     stop_id: "43000724302"
#     arrival {
#       delay: -8
#       time: 1700392192
#     }
#     departure {
#       delay: -8
#       time: 1700392192
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 66
#     stop_id: "43000707101"
#     arrival {
#       delay: -3
#       time: 1700392377
#     }
#     departure {
#       delay: -3
#       time: 1700392377
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 67
#     stop_id: "43000701301"
#     arrival {
#       delay: -26
#       time: 1700392474
#     }
#     departure {
#       delay: -26
#       time: 1700392474
#     }
#     schedule_relationship: SCHEDULED
#   }
#   stop_time_update {
#     stop_sequence: 68
#     stop_id: "43000700116"
#     arrival {
#       delay: -40
#       time: 1700392580
#     }
#     schedule_relationship: SCHEDULED
#   }
# }
